# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install chart-studio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting chart-studio
#   Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.9 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from chart-studio) (1.15.0)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (from chart-studio) (5.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from chart-studio) (2.23.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly->chart-studio) (8.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->chart-studio) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->chart-studio) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->chart-studio) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->chart-studio) (3.0.4)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11448 sha256=35a9d776449f78a95abd9a49f9024fa50383282166c820db72f4fc69649d76cc
#   Stored in directory: /root/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# Installing collected packages: retrying, chart-studio
# Successfully installed chart-studio-1.1.0 retrying-1.3.3

# %% [markdown]
# # Read and Overview Data

# %% [markdown]
# import all necessary modules

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot # plotly offline mode
init_notebook_mode(connected=True) 

import seaborn as sns
import cv2

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from tensorflow.keras.layers import BatchNormalization, Activation
# from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
import os
print(os.listdir("/content/drive/MyDrive/Flowers-Dataset.npy/flowers"))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ['daisy', 'dandelion', 'rose', 'tulip', 'sunflower']

# %%
# plotting a random image
img = plt.imread("/content/drive/MyDrive/Flowers-Dataset.npy/flowers/daisy/100080576_f52e8ee070_n.jpg")
img = cv2.resize(img,(124,124))
plt.imshow(img)
plt.axis("on")
plt.show()

# %% [markdown]
# Read all datas then create x and y datas

# %%
x_ = list()
y = list()
IMG_SIZE = 128
for i in os.listdir("/content/drive/MyDrive/Flowers-Dataset.npy/flowers/daisy"):
    try:
        path = "/content/drive/MyDrive/Flowers-Dataset.npy/flowers/daisy/"+i
        img = plt.imread(path)
        img = cv2.resize(img,(IMG_SIZE,IMG_SIZE))
        x_.append(img)
        y.append(0)
    except:
        None
for i in os.listdir("/content/drive/MyDrive/Flowers-Dataset.npy/flowers/dandelion"):
    try:
        path = "/content/drive/MyDrive/Flowers-Dataset.npy/flowers/dandelion/"+i
        img = plt.imread(path)
        img = cv2.resize(img,(IMG_SIZE,IMG_SIZE))
        x_.append(img)
        y.append(1)
    except:
        None
for i in os.listdir("/content/drive/MyDrive/Flowers-Dataset.npy/flowers/rose"):
    try:
        path = "/content/drive/MyDrive/Flowers-Dataset.npy/flowers/rose/"+i
        img = plt.imread(path)
        img = cv2.resize(img,(IMG_SIZE,IMG_SIZE))
        x_.append(img)
        y.append(2)
    except:
        None
for i in os.listdir("/content/drive/MyDrive/Flowers-Dataset.npy/flowers/sunflower"):
    try:
        path = "/content/drive/MyDrive/Flowers-Dataset.npy/flowers/sunflower/"+i
        img = plt.imread(path)
        img = cv2.resize(img,(IMG_SIZE,IMG_SIZE))
        x_.append(img)
        y.append(3)
    except:
        None
for i in os.listdir("/content/drive/MyDrive/Flowers-Dataset.npy/flowers/tulip"):
    try:
        path = "/content/drive/MyDrive/Flowers-Dataset.npy/flowers/tulip/"+i
        img = plt.imread(path)
        img = cv2.resize(img,(IMG_SIZE,IMG_SIZE))
        x_.append(img)
        y.append(4)
    except:
        None
x_ = np.array(x_)

# %% [markdown]
# let's see how the images look

# %%
#plottin one of all flower types in data
plt.figure(figsize = (20,20))
for i in range(5):
    img = x_[950*i]
    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis("off")
    plt.title(y[950*i])

# %% [markdown]
# # Data Preparation

# %% [markdown]
# replace flower types for the computer to understand

# %%
# for replacement process i'll use keras.to_categorical 
from keras.utils.np_utils import to_categorical
y = to_categorical(y,num_classes = 5)

# %%
# test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_,y,test_size = 0.15,random_state = 42)

# %%
# validation and trains split
x_train,x_val,y_train,y_val = train_test_split(x_train,y_train,test_size = 0.15,random_state = 42)

# %% [markdown]
# Plotting random 5 image in train data

# %%
plt.figure(figsize = (20,20))
for i in range(5):
    img = x_train[600*i]
    plt.subplot(1,5,i+1)
    plt.imshow(img)
    plt.axis("on")
    plt.title(y_train[600*i])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py:1165: FutureWarning:
#
# elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
x_train.shape # look traing shape
# Out:
# (3118, 128, 128, 3)

# %% [markdown]
# # Create CNN Model

# %% [markdown]
# Create Sequential model with using Keras

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (IMG_SIZE,IMG_SIZE,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 4th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 5th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Add output layer
model.add(Dense(5,activation="softmax"))

model.summary() # print summary my model
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy']) #compile model
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 64)       0
#  )
#
#  batch_normalization (BatchN  (None, 64, 64, 64)       256
#  ormalization)
#
#  dropout (Dropout)           (None, 64, 64, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 32, 32, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 512)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 4, 4, 512)        2048
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 1024)              8389632
#
#  dropout_5 (Dropout)         (None, 1024)              0
#
#  batch_normalization_5 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dense_1 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 10,101,765
# Trainable params: 10,097,541
# Non-trainable params: 4,224
# _________________________________________________________________

# %% [markdown]
# Compile model

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.

# %%
epoch = 30
batch_size = 64

# %% [markdown]
# Create a data augmentation and apply them x_train data

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=60,  # randomly rotate images in the range (60, 0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %% [markdown]
# # Train and Test the Model

# %%
history = model.fit_generator(datagen.flow(x_train,y_train,batch_size=batch_size),
                              epochs= epoch,validation_data=(x_val,y_val),
                              steps_per_epoch=x_train.shape[0] // batch_size
                              )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning:
#
# `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# 48/48 [==============================] - 412s 9s/step - loss: 1.5959 - accuracy: 0.4443 - val_loss: 5.9195 - val_accuracy: 0.3049
# Epoch 2/30
# 48/48 [==============================] - 413s 9s/step - loss: 1.2635 - accuracy: 0.5350 - val_loss: 2.3194 - val_accuracy: 0.4374
# Epoch 3/30
# 48/48 [==============================] - 417s 9s/step - loss: 1.0875 - accuracy: 0.5874 - val_loss: 1.2571 - val_accuracy: 0.5572
# Epoch 4/30
# 48/48 [==============================] - 419s 9s/step - loss: 1.0196 - accuracy: 0.6251 - val_loss: 1.0762 - val_accuracy: 0.6661
# Epoch 5/30
# 48/48 [==============================] - 420s 9s/step - loss: 0.9416 - accuracy: 0.6552 - val_loss: 2.0615 - val_accuracy: 0.4592
# Epoch 6/30
# 48/48 [==============================] - 412s 9s/step - loss: 0.9032 - accuracy: 0.6663 - val_loss: 0.9654 - val_accuracy: 0.6751
# Epoch 7/30
# 48/48 [==============================] - 414s 9s/step - loss: 0.8323 - accuracy: 0.6857 - val_loss: 0.9823 - val_accuracy: 0.6806
# Epoch 8/30
# 48/48 [==============================] - 414s 9s/step - loss: 0.8456 - accuracy: 0.6804 - val_loss: 1.2246 - val_accuracy: 0.6261
# Epoch 9/30
# 48/48 [==============================] - 412s 9s/step - loss: 0.7907 - accuracy: 0.6935 - val_loss: 0.9193 - val_accuracy: 0.7278
# Epoch 10/30
# 48/48 [==============================] - 410s 9s/step - loss: 0.7611 - accuracy: 0.7069 - val_loss: 0.8640 - val_accuracy: 0.6987
# Epoch 11/30
# 48/48 [==============================] - 411s 9s/step - loss: 0.7331 - accuracy: 0.7315 - val_loss: 0.9100 - val_accuracy: 0.6860
# Epoch 12/30
# 48/48 [==============================] - 408s 9s/step - loss: 0.7046 - accuracy: 0.7312 - val_loss: 0.8617 - val_accuracy: 0.7078
# Epoch 13/30
# 48/48 [==============================] - 413s 9s/step - loss: 0.7259 - accuracy: 0.7289 - val_loss: 0.7350 - val_accuracy: 0.7368
# Epoch 14/30
# 48/48 [==============================] - 412s 9s/step - loss: 0.6648 - accuracy: 0.7475 - val_loss: 1.0862 - val_accuracy: 0.6152
# Epoch 15/30
# 48/48 [==============================] - 404s 8s/step - loss: 0.6905 - accuracy: 0.7400 - val_loss: 1.0169 - val_accuracy: 0.6824
# Epoch 16/30
# 48/48 [==============================] - 406s 8s/step - loss: 0.6882 - accuracy: 0.7335 - val_loss: 0.8810 - val_accuracy: 0.7005
# Epoch 17/30
# 48/48 [==============================] - 409s 9s/step - loss: 0.6218 - accuracy: 0.7633 - val_loss: 1.1022 - val_accuracy: 0.6751
# Epoch 18/30
# 48/48 [==============================] - 405s 8s/step - loss: 0.6097 - accuracy: 0.7809 - val_loss: 0.8073 - val_accuracy: 0.7278
# Epoch 19/30
# 48/48 [==============================] - 408s 9s/step - loss: 0.6091 - accuracy: 0.7705 - val_loss: 0.7285 - val_accuracy: 0.7731
# Epoch 20/30
# 48/48 [==============================] - 401s 8s/step - loss: 0.5620 - accuracy: 0.7780 - val_loss: 0.7616 - val_accuracy: 0.7623
# Epoch 21/30
# 48/48 [==============================] - 402s 8s/step - loss: 0.5779 - accuracy: 0.7724 - val_loss: 0.9988 - val_accuracy: 0.7042
# Epoch 22/30
# 48/48 [==============================] - 400s 8s/step - loss: 0.5620 - accuracy: 0.7806 - val_loss: 0.6756 - val_accuracy: 0.7731
# Epoch 23/30
# 48/48 [==============================] - 403s 8s/step - loss: 0.5278 - accuracy: 0.8009 - val_loss: 1.0208 - val_accuracy: 0.6751
# Epoch 24/30
# 48/48 [==============================] - 399s 8s/step - loss: 0.5406 - accuracy: 0.7954 - val_loss: 0.9645 - val_accuracy: 0.7096
# Epoch 25/30
# 48/48 [==============================] - 402s 8s/step - loss: 0.5345 - accuracy: 0.7980 - val_loss: 0.7459 - val_accuracy: 0.7423
# Epoch 26/30
# 48/48 [==============================] - 402s 8s/step - loss: 0.5051 - accuracy: 0.8084 - val_loss: 0.7625 - val_accuracy: 0.7550
# Epoch 27/30
# 48/48 [==============================] - 401s 8s/step - loss: 0.5132 - accuracy: 0.8016 - val_loss: 0.7022 - val_accuracy: 0.7604
# Epoch 28/30
# 48/48 [==============================] - 401s 8s/step - loss: 0.4926 - accuracy: 0.8134 - val_loss: 0.8222 - val_accuracy: 0.7060
# Epoch 29/30
# 48/48 [==============================] - 401s 8s/step - loss: 0.4776 - accuracy: 0.8225 - val_loss: 0.6861 - val_accuracy: 0.7985
# Epoch 30/30
# 48/48 [==============================] - 402s 8s/step - loss: 0.4796 - accuracy: 0.8189 - val_loss: 0.6624 - val_accuracy: 0.7713

# %% [markdown]
# # Plotting Results

# %%
print("Test Accuracy: {0:.2f}%".format(model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 21/21 [==============================] - 17s 827ms/step - loss: 0.7046 - accuracy: 0.7531
# Test Accuracy: 75.31%

# %%
train_loss = history.history['loss'], # get loss values from the history
train_acc = history.history['accuracy']
#plt.plot(train_loss, '-x')
plt.plot(train_acc, '-x')
plt.xlabel('epoch')
plt.ylabel('training accuracy')
#plt.legend(['Training loss', 'Training accuracy'])
plt.title('Training Accuracy with each epoch');

# %%
#train_loss = history.history['loss'], # get loss values from the history
val_acc = history.history['val_accuracy']
#plt.plot(train_loss, '-x')
plt.plot(val_acc, '-rx')
plt.xlabel('epoch')
plt.ylabel('accuracy')
#plt.legend(['Training loss', 'Training accuracy'])
plt.title('Validation Accuracy with each epoch');

# %%
from sklearn.metrics import confusion_matrix
Y_pred = model.predict(x_val)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_val,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()
# Out:
# 18/18 [==============================] - 20s 1s/step
